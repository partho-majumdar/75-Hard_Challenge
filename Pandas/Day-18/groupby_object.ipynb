# %%
import numpy as np # type: ignore
import pandas as pd # type: ignore

# %%
movies = pd.read_csv('./imdb-top-1000.csv')
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
# Groupby -> make group in data on the basis of some column (categorical)

movies
genres = movies.groupby('Genre')

genres.apply(lambda x:x, include_groups = False)
# genres.apply(lambda x:x)
genres.min()
genres.max()
genres.sum()
# Out:
#                                                 Series_Title  \
# Genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...
# Adventure  InterstellarBack to the FutureInglourious Bast...
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...
# Crime      The GodfatherThe Godfather: Part II12 Angry Me...
# Drama      The Shawshank RedemptionFight ClubForrest Gump...
# Family     E.T. the Extra-TerrestrialWilly Wonka & the Ch...
# Fantasy                Das Cabinet des Dr. CaligariNosferatu
# Film-Noir   The Third ManThe Maltese FalconShadow of a Doubt
# Horror     PsychoAlienThe ThingThe ExorcistNight of the L...
# Mystery    MementoRear WindowVertigoShutter IslandKahaani...
# Thriller                                     Wait Until Dark
# Western    Il buono, il brutto, il cattivoOnce Upon a Tim...
#
# ...

# %%
# Find top 3 genres by total earning

movies.groupby('Genre')['Gross'].sum().sort_values(ascending = False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# find the genre with highest avg IMDB rating

movies.groupby('Genre')['IMDB_Rating']
movies.groupby('Genre')['IMDB_Rating'].mean()
movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending = False).head(3)
# Out:
# Genre
# Western    8.350000
# Crime      8.016822
# Fantasy    8.000000
# Name: IMDB_Rating, dtype: float64

# %%
# find director with most popularity

movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending = False).head(3)
# Out:
# Director
# Christopher Nolan    11578345
# Quentin Tarantino     8123208
# Steven Spielberg      7817166
# Name: No_of_Votes, dtype: int64

# %%
# find number of movies done by each actor
# 1. Convert into group
# 2. Select column
# 3. Use aggregate operation

movies['Star1'].value_counts().head(5) # R1
movies.groupby('Star1')['Series_Title'].count().sort_values(ascending = False).head(5) # R2
# Out:
# Star1
# Tom Hanks            12
# Robert De Niro       11
# Al Pacino            10
# Clint Eastwood       10
# Leonardo DiCaprio     9
# Name: Series_Title, dtype: int64

# %%
# find total number of group

len(movies.groupby('Genre')) # R1
movies['Genre'].nunique() # R2
# Out:
# 14

# %%
# find item(row) in each group

movies.groupby('Genre').size().sort_values(ascending = False) # R1
movies['Genre'].value_counts() # R2
# Out:
# Genre
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: count, dtype: int64

# %%
# find first and last item from each group

genres = movies.groupby('Genre')
genres.first()
genres.last()
genres.nth(6) # 7th movie of each group (group start with 0)
# Out:
#                                        Series_Title Released_Year  Runtime  \
# 16   Star Wars: Episode V - The Empire Strikes Back          1980      124
# 27                                            Se7en          1995      127
# 32                            It's a Wonderful Life          1946      130
# 66                                           WALL·E          2008       98
# 83                               The Great Dictator          1940      125
# 102                                      Braveheart          1995      178
# 118                              North by Northwest          1959      136
# 420                                          Sleuth          1972      138
# 724                                         Get Out          2017      104
#
#          Genre  IMDB_Rating              Director             Star1  \
# 16      Action          8.7        Irvin Kershner       Mark Hamill
# 27       Crime          8.6         David Fincher    Morgan Freeman
# ...

# %%
# get_group -> details of particular group

genres.get_group('Horror') # R1
movies[movies['Genre'] == 'Horror'] # R2
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 49                     Psycho          1960      109  Horror          8.5
# 75                      Alien          1979      117  Horror          8.4
# 271                 The Thing          1982      109  Horror          8.1
# 419              The Exorcist          1973      122  Horror          8.0
# 544  Night of the Living Dead          1968       96  Horror          7.9
# 707             The Innocents          1961      100  Horror          7.8
# 724                   Get Out          2017      104  Horror          7.7
# 844                 Halloween          1978       91  Horror          7.7
# 876         The Invisible Man          1933       71  Horror          7.7
# 932                       Saw          2004      103  Horror          7.6
# 948                The Others          2001      101  Horror          7.6
#
#                Director             Star1  No_of_Votes        Gross  Metascore
# ...

# %%
# which group contains which index item

genres.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
genres.describe()
genres.sample() # 1 random value from each genre
genres.sample(2, replace = True) # 2 random value from each genre if not available repeat first
genres.nunique() # nunique() for -> return count
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %%
# multiple aggregation (agg method) -> pass dictionary

genres.sum()
genres.agg(
    {
        'Runtime': 'mean',
        'IMDB_Rating': 'mean',
        'No_of_Votes': 'sum',
        'Metascore': 'min'
    }
)
# Out:
#               Runtime  IMDB_Rating  No_of_Votes  Metascore
# Genre
# Action     129.046512     7.949419     72282412       33.0
# Adventure  134.111111     7.937500     22576163       41.0
# Animation   99.585366     7.930488     21978630       61.0
# Biography  136.022727     7.938636     24006844       48.0
# Comedy     112.129032     7.901290     27620327       45.0
# Crime      126.392523     8.016822     33533615       47.0
# Drama      124.737024     7.957439     61367304       28.0
# Family     107.500000     7.800000       551221       67.0
# Fantasy     85.000000     8.000000       146222        NaN
# Film-Noir  104.000000     7.966667       367215       94.0
# Horror     102.090909     7.909091      3742556       46.0
# Mystery    119.083333     7.975000      4203004       52.0
# Thriller   108.000000     7.800000        27733       81.0
# Western    148.250000     8.350000      1289665       69.0

# %%
# multiple aggregation -> pass list

genres[['Runtime', 'IMDB_Rating']].agg(['min', 'max', 'mean'])
# Out:
#           Runtime                  IMDB_Rating
#               min  max        mean         min  max      mean
# Genre
# Action         45  321  129.046512         7.6  9.0  7.949419
# Adventure      88  228  134.111111         7.6  8.6  7.937500
# Animation      71  137   99.585366         7.6  8.6  7.930488
# Biography      93  209  136.022727         7.6  8.9  7.938636
# Comedy         68  188  112.129032         7.6  8.6  7.901290
# Crime          80  229  126.392523         7.6  9.2  8.016822
# Drama          64  242  124.737024         7.6  9.3  7.957439
# Family        100  115  107.500000         7.8  7.8  7.800000
# Fantasy        76   94   85.000000         7.9  8.1  8.000000
# Film-Noir     100  108  104.000000         7.8  8.1  7.966667
# Horror         71  122  102.090909         7.6  8.5  7.909091
# Mystery        96  138  119.083333         7.6  8.4  7.975000
# Thriller      108  108  108.000000         7.8  7.8  7.800000
# ...

# %%
# combined both

genres.agg(
    {
        'Runtime': ['mean', 'max'],
        'IMDB_Rating': 'mean',
        'No_of_Votes': ['sum', 'min'],
        'Metascore': 'min'
    }
)
# Out:
#               Runtime      IMDB_Rating No_of_Votes         Metascore
#                  mean  max        mean         sum     min       min
# Genre
# Action     129.046512  321    7.949419    72282412   25312      33.0
# Adventure  134.111111  228    7.937500    22576163   29999      41.0
# Animation   99.585366  137    7.930488    21978630   25229      61.0
# Biography  136.022727  209    7.938636    24006844   27254      48.0
# Comedy     112.129032  188    7.901290    27620327   26337      45.0
# Crime      126.392523  229    8.016822    33533615   27712      47.0
# Drama      124.737024  242    7.957439    61367304   25088      28.0
# Family     107.500000  115    7.800000      551221  178731      67.0
# Fantasy     85.000000   94    8.000000      146222   57428       NaN
# Film-Noir  104.000000  108    7.966667      367215   59556      94.0
# Horror     102.090909  122    7.909091     3742556   27007      46.0
# ...

# %%
# looping on group

for group, data in genres:
    print(group, data) # dataframe
# Out:
# Action                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
# find the highest rated movie of each 

df = pd.DataFrame(columns = movies.columns)

genres = movies.groupby('Genre')
for group, data in genres:
    filtered_data = data[data['IMDB_Rating'] == data['IMDB_Rating'].max()]
    df = pd.concat([df, filtered_data])
df
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12676\113838990.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, filtered_data])
#                             Series_Title Released_Year Runtime      Genre  \
# 2                        The Dark Knight          2008     152     Action
# 21                          Interstellar          2014     169  Adventure
# 23         Sen to Chihiro no kamikakushi          2001     125  Animation
# 7                       Schindler's List          1993     195  Biography
# 19                          Gisaengchung          2019     132     Comedy
# 26                       La vita è bella          1997     116     Comedy
# ...

# %%
# split - apply 

genres.apply(max, include_groups = False)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12676\4255852692.py:3: FutureWarning: The provided callable <built-in function max> is currently using np.maximum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.maximum.reduce instead.
#   genres.apply(max, include_groups = False)
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                                 Yôjinbô          2019      321
# Adventure                           Zombieland            PG      228
# Animation          Ôkami kodomo no Ame to Yuki          2020      137
# Biography                              Zerkalo          2020      209
# Comedy                Zindagi Na Milegi Dobara          2020      188
# Crime                        À bout de souffle          2019      229
# Drama                                Zwartboek          2020      242
# ...

# %%
# find number of movies starting with A for each group

def func(data):
    return data['Series_Title'].str.startswith('A').sum()

genres.apply(func)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12676\1879589998.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(func)
# Genre
# Action       10
# Adventure     2
# Animation     2
# Biography     9
# Comedy       14
# Crime         4
# Drama        21
# Family        0
# Fantasy       0
# Film-Noir     0
# Horror        1
# Mystery       0
# Thriller      0
# Western       0
# dtype: int64

# %%
# find ranking of each movie in the group according to IMDB rating

def func1(data):
    data['genre_rank'] = data['IMDB_Rating'].rank(ascending = False)
    return data

genres.apply(func1)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12676\1673517032.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(func1)
#                                                    Series_Title Released_Year  \
# Genre
# Action   2                                      The Dark Knight          2008
#          5        The Lord of the Rings: The Return of the King          2003
#          8                                            Inception          2010
#          10   The Lord of the Rings: The Fellowship of the Ring          2001
#          13               The Lord of the Rings: The Two Towers          2002
# ...

# %%
# find normalized (X - Xmin) / (Xmax - Xmin) IMDB rating group wise

def func2(data):
    data['norm_rank'] = (data['IMDB_Rating'] - data['IMDB_Rating'].min()) / (data['IMDB_Rating'].max() - data['IMDB_Rating'].min())
    return data

genres.apply(func2)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12676\586233512.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(func2)
#                                                    Series_Title Released_Year  \
# Genre
# Action   2                                      The Dark Knight          2008
#          5        The Lord of the Rings: The Return of the King          2003
#          8                                            Inception          2010
#          10   The Lord of the Rings: The Fellowship of the Ring          2001
#          13               The Lord of the Rings: The Two Towers          2002
# ...

# %%
# groupby on multiple columns
duo = movies.groupby(['Director', 'Star1'])
# duo.size()

# get_group -> get particular group
duo.get_group(('Aamir Khan', 'Amole Gupte'))
# Out:
#         Series_Title Released_Year  Runtime  Genre  IMDB_Rating    Director  \
# 65  Taare Zameen Par          2007      165  Drama          8.4  Aamir Khan
#
#           Star1  No_of_Votes      Gross  Metascore
# 65  Amole Gupte       168895  1223869.0        NaN

# %%
# most earning actor-director combo

duo['Gross'].sum().sort_values(ascending = False)
# Out:
# Director              Star1
# Akira Kurosawa        Toshirô Mifune     2.999877e+09
# Anthony Russo         Joe Russo          2.205039e+09
# Billy Wilder          William Holden     1.286779e+09
# Christopher Nolan     Christian Bale     1.242940e+09
# Werner Herzog         Klaus Kinski       1.124605e+09
#                                              ...
# Jeong-beom Lee        Won Bin            6.460000e+03
# Shane Meadows         Paddy Considine    6.013000e+03
# Jaco Van Dormael      Jared Leto         3.600000e+03
# Thomas Jahn           Til Schweiger      3.296000e+03
# Anders Thomas Jensen  Ulrich Thomsen     1.305000e+03
# Name: Gross, Length: 898, dtype: float64

# %%
# find best(in term of meta score(avg)) actor-genre combo 

movies.groupby(['Star1', 'Genre'])['Metascore'].mean() # this is series
movies.groupby(['Star1', 'Genre'])['Metascore'].mean().reset_index() # this is dataframe
movies.groupby(['Star1', 'Genre'])['Metascore'].mean().reset_index().sort_values('Metascore', ascending = False)
# Out:
#                 Star1      Genre  Metascore
# 77        Bertil Guve      Drama      100.0
# 590      Orson Welles      Drama      100.0
# 606     Peter O'Toole  Adventure      100.0
# 329   Humphrey Bogart      Drama      100.0
# 127        Cary Grant      Drama      100.0
# ..                ...        ...        ...
# 807    William Holden      Drama        NaN
# 812           Won Bin     Action        NaN
# 815              Yash     Action        NaN
# 826    Çetin Tekindor      Drama        NaN
# 828  Ömer Faruk Sorak     Comedy        NaN
#
# [829 rows x 3 columns]

# %%
# agg on multiple groupby

duo.agg(['min', 'max'])
# Out:
#                                                   Series_Title  \
#                                                            min
# Director            Star1
# Aamir Khan          Amole Gupte               Taare Zameen Par
# Aaron Sorkin        Eddie Redmayne  The Trial of the Chicago 7
# Abdellatif Kechiche Léa Seydoux                 La vie d'Adèle
# Abhishek Chaubey    Shahid Kapoor                  Udta Punjab
# Abhishek Kapoor     Amit Sadh                      Kai po che!
# ...                                                        ...
# Zaza Urushadze      Lembit Ulfsak                  Mandariinid
# Zoya Akhtar         Hrithik Roshan    Zindagi Na Milegi Dobara
#                     Vijay Varma                      Gully Boy
# Çagan Irmak         Çetin Tekindor              Babam ve Oglum
# Ömer Faruk Sorak    Cem Yilmaz                        G.O.R.A.
#
#                                                                Released_Year  \
# ...

# %%
ipl = pd.read_csv('./deliveries.csv')
ipl.shape
# Out:
# (179078, 21)

# %%
# find top 10 batsman in terms of runs

ipl.groupby('batsman')['batsman_runs'].sum().sort_values(ascending = False).head(10)
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
# find the batsman with max number of six

# ipl
six = ipl[ipl['batsman_runs'] == 6]
six.groupby('batsman')['batsman_runs'].count().sort_values(ascending = False).head(10)
# Out:
# batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
# V Kohli           191
# DA Warner         181
# SR Watson         177
# KA Pollard        175
# YK Pathan         161
# Name: batsman_runs, dtype: int64

# %%
# find batsman with most number of 4's and 6's in last 5 overs

temp_df = ipl[ipl['over'] > 15]
temp_df1 = temp_df[(temp_df['batsman_runs'] == 4) | (temp_df['batsman_runs'] == 6)]
temp_df1.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False).head(10)
# Out:
# batsman
# MS Dhoni          340
# RG Sharma         208
# AB de Villiers    208
# KA Pollard        206
# V Kohli           160
# YK Pathan         149
# KD Karthik        145
# Yuvraj Singh      130
# AD Russell        129
# AT Rayudu         114
# Name: batsman_runs, dtype: int64

# %%
# Find V Kohli's record against all team

temp_df = ipl[ipl['batsman'] == 'V Kohli']
temp_df.groupby('bowling_team')['batsman_runs'].sum() # series
temp_df.groupby('bowling_team')['batsman_runs'].sum().reset_index() # dataframe
# Out:
#                bowling_team  batsman_runs
# 0       Chennai Super Kings           749
# 1           Deccan Chargers           306
# 2            Delhi Capitals            66
# 3          Delhi Daredevils           763
# 4             Gujarat Lions           283
# 5           Kings XI Punjab           636
# 6      Kochi Tuskers Kerala            50
# 7     Kolkata Knight Riders           675
# 8            Mumbai Indians           628
# 9             Pune Warriors           128
# 10         Rajasthan Royals           370
# 11   Rising Pune Supergiant            83
# 12  Rising Pune Supergiants           188
# 13      Sunrisers Hyderabad           509

# %%
# create a function that can return the highest score of any batsman

temp_df = ipl[ipl['batsman'] == 'V Kohli']
temp_df.groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False).head(1).values[0]

def high_score(batsman):
    temp_df = ipl[ipl['batsman'] == batsman]
    return temp_df.groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False).head(1).values[0]

high_score('V Kohli')
# Out:
# np.int64(113)
