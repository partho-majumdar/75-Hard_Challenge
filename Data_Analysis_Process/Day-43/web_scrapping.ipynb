# %%
''' 
In few website sometimes i have to click on "load more" for more products to interact with these i need to use selenium 
'''
# Out:
# ' \nIn few website sometimes i have to click on "load more" for more products to interact with these i need to use selenium \n'

# %%
with open('asos.html', 'r', encoding='utf-8') as f:
    html = f.read()

# %%
html
# Out:
# '<html lang="en-GB" data-platform="desktop" data-store-code="ROW" data-country-code="BD" data-gender="men"><head><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-H5HS29D9X2&amp;l=gtmDataLayer&amp;cx=c&amp;gtm=45He4cc1v852467913za200" nonce=""></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/destination?id=AW-981830880&amp;l=gtmDataLayer&amp;cx=c&amp;gtm=45He4cc1v852467913za200" nonce=""></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/destination?id=DC-11229815&amp;l=gtmDataLayer&amp;cx=c&amp;gtm=45He4cc1v852467913za200" nonce=""></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/destination?id=DC-9827385&amp;l=gtmDataLayer&amp;cx=c&amp;gtm=45He4cc1v852467913za200" nonce=""></script><script type="text/javascript" src="https://bam.nr-data.net/1/3edea625b0?a=1103197001&amp;sa=1&amp;v=1210.e2a3f80&amp;t=Unnamed%20Transac
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup('html', 'lxml')
soup.prettify()
# Out:
# '<html>\n <body>\n  <p>\n   html\n  </p>\n </body>\n</html>\n'
