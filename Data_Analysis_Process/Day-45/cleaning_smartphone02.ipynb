# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("./smartphones01.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      982 non-null    int64
#  1   model      982 non-null    object
#  2   price      982 non-null    int64
#  3   rating     879 non-null    float64
#  4   sim        982 non-null    object
#  5   processor  982 non-null    object
#  6   ram        982 non-null    object
#  7   battery    971 non-null    object
#  8   display    982 non-null    object
#  9   camera     982 non-null    object
#  10  card       982 non-null    object
#  11  os         967 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 92.2+ KB

# %%
brand_names = df1['model'].str.split(' ').str.get(0)

# %%
df1.insert(1,'brand_name',brand_names)

# %%
df1['brand_name'] = df1['brand_name'].str.lower()

# %%
has_5g = df1['sim'].str.contains('5G')
has_nfc = df1['sim'].str.contains('NFC')
has_ir_blaster = df1['sim'].str.contains('IR Blaster')

# %%
df1.insert(6,'has_5g',has_5g)
df1.insert(7,'has_nfc',has_nfc)
df1.insert(8,'has_ir_blaster',has_ir_blaster)

# %%
processor_name = df1['processor'].str.split(',').str.get(0)

# %%
num_cores = df1['processor'].str.split(',').str.get(1)

# %%
processor_speed = df1['processor'].str.split(',').str.get(2)

# %%
df1.insert(10,'processor_name',processor_name)
df1.insert(11,'num_cores',num_cores)
df1.insert(12,'processor_speed',processor_speed)

# %%
df1['processor_name'] = df1['processor_name'].str.strip()

# %%
temp_df = df1[df1['processor_name'].str.contains('Core')][['processor_name', 'num_cores',	'processor_speed']].shift(1,axis=1)

# %%
temp_df.shape
# Out:
# (20, 3)

# %%
df1.loc[temp_df.index,['processor_name', 'num_cores',	'processor_speed']] = temp_df.values

# %%
df1.loc[856]
# Out:
# index                                                            889
# brand_name                                                   infinix
# model                                            Infinix Note 12 VIP
# price                                                          19999
# rating                                                          84.0
# sim                                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# has_5g                                                         False
# has_nfc                                                        False
# has_ir_blaster                                                 False
# processor                  Helio  G96, Octa Core, 2.05 GHz Processor
# processor_name                                            Helio  G96
# num_cores                                                  Octa Core
# processor_speed                                   2.05 GHz Processor
# ram                                         8 GB RAM, 128 GB inbuilt
# battery                     4500 mAh Battery with 120W Fast Charging
# display            6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# camera             108 MP + 13 MP + 2 MP Triple Rear & 16 MP Fron...
# card                              Memory Card Supported, upto 256 GB
# os                                                       Android v12
# Name: 856, dtype: object

# %%
df1.loc[856,'processor_name'] = 'Mediatek MT6739'

# %%
processor_brand = df1['processor_name'].str.split(' ').str.get(0).str.lower()

# %%
df1.insert(11,'processor_brand',processor_brand)

# %%
df1['num_cores'] = df1['num_cores'].str.strip()

# %%
df1['num_cores'] = df1['num_cores'].str.replace('Octa Core Processor','Octa Core').str.replace('Hexa Core Processor','Hexa Core')

# %%
df1['processor_speed'] = df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0).astype(float)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 2          exynos  Octa Core              2.4    4 GB RAM, 64 GB inbuilt
# 3      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 4       dimensity  Octa Core              2.6   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
ram_capacity = df1['ram'].str.strip().str.split(',').str.get(0).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(16,'ram_capacity',ram_capacity)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 2          exynos  Octa Core              2.4    4 GB RAM, 64 GB inbuilt
# 3      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 4       dimensity  Octa Core              2.6   6 GB RAM, 128 GB inbuilt
#
#                                     battery ram_capacity  \
# 0  5000 mAh Battery with 100W Fast Charging           12
# 1   5000 mAh Battery with 33W Fast Charging            6
# 2   5000 mAh Battery with 15W Fast Charging            4
# 3       5000 mAh Battery with Fast Charging            6
# 4   5000 mAh Battery with 67W Fast Charging            6
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
internal_memory = df1['ram'].str.strip().str.split(',').str.get(1).str.strip().str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(17,'internal_memory',internal_memory)

# %%
df1['ram_capacity'] = df1['ram_capacity'].astype(float)

# %%
df1.drop([486,627],inplace=True)

# %%
df1.loc[[483], ['ram_capacity','internal_memory']] = [12.0,'512']

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8.0      337
# 6.0      234
# 4.0      214
# 12.0      86
# 3.0       54
# 2.0       32
# 16.0       9
# 1.0        7
# 64.0       3
# 18.0       2
# 512.0      2
# Name: count, dtype: int64

# %%
df1['internal_memory'] = df1['internal_memory'].astype(float)

# %%
temp_df = df1[df1['internal_memory'] == 1]

# %%
df1.loc[temp_df.index,'internal_memory'] = 1024

# %%
df1['internal_memory'].value_counts()
# Out:
# internal_memory
# 128.0     522
# 64.0      191
# 256.0     156
# 32.0       67
# 512.0      22
# 16.0       12
# 1024.0      5
# 4.0         1
# 8.0         1
# Name: count, dtype: int64

# %%
battery_capacity = df1['battery'].str.strip().str.split('with').str.get(0).str.strip().str.findall(r'\b(\d+)\b').str.get(0).astype(float)

# %%
df1.insert(16,'battery_capacity',battery_capacity)

# %%
fast_charging = df1['battery'].str.strip().str.split('with').str.get(1).str.strip().str.findall(r'\d{2,3}')

# %%
df1.insert(17,'fast_charging',fast_charging)

# %%
def fast_charging_extractor(item):

  if type(item) == list:
    if len(item) == 1:
      return item[0]
    else:
      return 0
  else:
    return -1

# %%
df1['fast_charging'] = df1['fast_charging'].apply(fast_charging_extractor).astype(int)

# %%
screen_size = df1['display'].str.strip().str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype(float)

# %%
df1.insert(21,'screen_size',screen_size)

# %%
resolution = df1['display'].str.strip().str.split(',').str.get(1).str.strip().str.split('px').str.get(0)

# %%
df1.insert(22,'resolution',resolution)

# %%
refresh_rate = df1['display'].str.strip().str.split(',').str.get(2).str.strip().str.findall(r'\d{2,3}').str.get(0).apply(lambda x: 60 if pd.isna(x) else x).astype(int)

# %%
df1.insert(22,'refresh_rate',refresh_rate)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 2          exynos  Octa Core              2.4    4 GB RAM, 64 GB inbuilt
# 3      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 4       dimensity  Octa Core              2.6   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging            5000.0            100
# 1   5000 mAh Battery with 33W Fast Charging            5000.0             33
# 2   5000 mAh Battery with 15W Fast Charging            5000.0             15
# 3       5000 mAh Battery with Fast Charging            5000.0              0
# 4   5000 mAh Battery with 67W Fast Charging            5000.0             67
#
#    ram_capacity  internal_memory  \
# 0          12.0            256.0
# 1           6.0            128.0
# 2           4.0             64.0
# 3           6.0            128.0
# 4           6.0            128.0
#
#                                              display  screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...         6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...         6.59
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...         6.60
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...         6.55
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...         6.70
#
#    refresh_rate    resolution  \
# 0           120  1440 x 3216
# 1           120  1080 x 2412
# 2            90  1080 x 2408
# 3           120  1080 x 2400
# 4           120  1080 x 2412
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
def camera_extractor(text):

  if 'Quad' in text:
    return '4'
  elif 'Triple' in text:
    return '3'
  elif 'Dual' in text:
    return '2'
  elif 'Missing' in text:
    return 'Missing'
  else:
    return '1'

# %%
num_rear_cameras = df1['camera'].str.strip().str.split('&').str.get(0).apply(camera_extractor)

# %%
df1.insert(25,'num_rear_cameras',num_rear_cameras)

# %%
num_front_cameras = df1['camera'].str.strip().str.split('&').str.get(1).str.strip().fillna('Missing').apply(camera_extractor)

# %%
df1.insert(26,'num_front_cameras',num_front_cameras)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 2          exynos  Octa Core              2.4    4 GB RAM, 64 GB inbuilt
# 3      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 4       dimensity  Octa Core              2.6   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging            5000.0            100
# 1   5000 mAh Battery with 33W Fast Charging            5000.0             33
# 2   5000 mAh Battery with 15W Fast Charging            5000.0             15
# 3       5000 mAh Battery with Fast Charging            5000.0              0
# 4   5000 mAh Battery with 67W Fast Charging            5000.0             67
#
#    ram_capacity  internal_memory  \
# 0          12.0            256.0
# 1           6.0            128.0
# 2           4.0             64.0
# 3           6.0            128.0
# 4           6.0            128.0
#
#                                              display  screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...         6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...         6.59
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...         6.60
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...         6.55
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...         6.70
#
#    refresh_rate    resolution  \
# 0           120  1440 x 3216
# 1           120  1080 x 2412
# 2            90  1080 x 2408
# 3           120  1080 x 2400
# 4           120  1080 x 2412
#
#                                               camera num_rear_cameras  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...                3
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...                3
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...                3
#
#   num_front_cameras                              card           os
# 0                 1         Memory Card Not Supported  Android v13
# 1                 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2                 1  Memory Card Supported, upto 1 TB  Android v13
# 3                 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 4                 1         Memory Card Not Supported  Android v13

# %%
df1[df1['num_front_cameras'] == 'Missing']
# Out:
#      index brand_name                model   price  rating  \
# 69      71       oppo     Oppo Find N Fold   99990     NaN
# 458    464     xiaomi  Xiaomi Mi Mix Alpha  199990     NaN
# 481    488      nokia        Nokia 8000 4G    6899     NaN
# 614    629      nokia         Nokia 225 4G    3589     NaN
# 956    995     huawei        Huawei Mate X  169000     NaN
# 974   1014       itel            itel A23s    4787     NaN
#
#                                                    sim  has_5g  has_nfc  \
# 69             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 458                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 481                            Dual Sim, 3G, 4G, Wi-Fi   False    False
# 614                            Dual Sim, 3G, 4G, VoLTE   False    False
# 956  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 974                            Dual Sim, 3G, 4G, Wi-Fi   False    False
#
#      has_ir_blaster                                          processor  \
# 69            False  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 458           False     Snapdragon 855+, Octa Core, 2.96 GHz Processor
# 481           False      Snapdragon  210, Quad Core, 1.1 GHz Processor
# 614           False                                        Unisoc T117
# 956            True          Kirin  990, Octa Core, 2.86 GHz Processor
# 974           False  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor
#
#           processor_name processor_brand  num_cores  processor_speed  \
# 69   Snapdragon  8+ Gen1      snapdragon  Octa Core             3.20
# 458      Snapdragon 855+      snapdragon  Octa Core             2.96
# 481      Snapdragon  210      snapdragon  Quad Core             1.10
# 614          Unisoc T117          unisoc        NaN              NaN
# 956           Kirin  990           kirin  Octa Core             2.86
# 974  Spreadtrum  SC9832E      spreadtrum  Quad Core             1.40
#
#                            ram                                  battery  \
# 69    8 GB RAM, 256 GB inbuilt  5000 mAh Battery with 67W Fast Charging
# 458  12 GB RAM, 512 GB inbuilt  4050 mAh Battery with 40W Fast Charging
# 481   512 MB RAM, 4 GB inbuilt                         1500 mAh Battery
# 614  64 MB RAM, 128 MB inbuilt                         1150 mAh Battery
# 956   8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
# 974    2 GB RAM, 32 GB inbuilt                         3020 mAh Battery
#
#      battery_capacity  fast_charging  ram_capacity  internal_memory  \
# 69             5000.0             67           8.0            256.0
# 458            4050.0             40          12.0            512.0
# 481            1500.0             -1         512.0              4.0
# 614            1150.0             -1          64.0            128.0
# 956            4500.0             55           8.0            512.0
# 974            3020.0             -1           2.0             32.0
#
#                                                display  screen_size  \
# 69   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...         7.10
# 458                7.92 inches, 2088 x 2250 px Display         7.92
# 481                   2.8 inches, 240 x 320 px Display         2.80
# 614                   2.4 inches, 240 x 320 px Display         2.40
# 956                   8 inches, 2200 x 2480 px Display         8.00
# 974                     5 inches, 854 x 480 px Display         5.00
#
#      refresh_rate    resolution                                     camera  \
# 69            120  1792 x 1920              Foldable Display, Dual Display
# 458            60  2088 x 2250   108 MP + 20 MP + 12 MP Triple Rear Camera
# 481            60    240 x 320                            2 MP Rear Camera
# 614            60    240 x 320                          0.3 MP Rear Camera
# 956            60  2200 x 2480                      48 MP Quad Rear Camera
# 974            60    854 x 480                            2 MP Rear Camera
#
#     num_rear_cameras num_front_cameras                               card  \
# 69                 2           Missing          Memory Card Not Supported
# 458                3           Missing          Memory Card Not Supported
# 481                1           Missing              Memory Card Supported
# 614                1           Missing  Memory Card Supported, upto 32 GB
# 956                4           Missing          Memory Card Not Supported
# 974                1           Missing          Memory Card Not Supported
#
#                     os
# 69         Android v12
# 458        Android v10
# 481                NaN
# 614  RTOS (Series 30+)
# 956                NaN
# 974        Android v11

# %%
pd.set_option('display.max_columns',None)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 2          exynos  Octa Core              2.4    4 GB RAM, 64 GB inbuilt
# 3      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 4       dimensity  Octa Core              2.6   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging            5000.0            100
# 1   5000 mAh Battery with 33W Fast Charging            5000.0             33
# 2   5000 mAh Battery with 15W Fast Charging            5000.0             15
# 3       5000 mAh Battery with Fast Charging            5000.0              0
# 4   5000 mAh Battery with 67W Fast Charging            5000.0             67
#
#    ram_capacity  internal_memory  \
# 0          12.0            256.0
# 1           6.0            128.0
# 2           4.0             64.0
# 3           6.0            128.0
# 4           6.0            128.0
#
#                                              display  screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...         6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...         6.59
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...         6.60
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...         6.55
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...         6.70
#
#    refresh_rate    resolution  \
# 0           120  1440 x 3216
# 1           120  1080 x 2412
# 2            90  1080 x 2408
# 3           120  1080 x 2400
# 4           120  1080 x 2412
#
#                                               camera num_rear_cameras  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...                3
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...                3
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...                3
#
#   num_front_cameras                              card           os
# 0                 1         Memory Card Not Supported  Android v13
# 1                 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2                 1  Memory Card Supported, upto 1 TB  Android v13
# 3                 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 4                 1         Memory Card Not Supported  Android v13

# %%
#df1[df1['camera'] == 'Foldable Display, Dual Display']
df1.loc[69,'camera'] == '50 MP'
# Out:
# False

# %%
temp_df = df1[df1['camera'] == 'Foldable Display, Dual Display']

# %%
df1.loc[temp_df.index, 'camera'] = '50 MP'

# %%
df1['primary_camera_rear'] = df1['camera'].str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df1['primary_camera_front'] = df1['camera'].str.split('&').str.get(1).str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 2          exynos  Octa Core              2.4    4 GB RAM, 64 GB inbuilt
# 3      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 4       dimensity  Octa Core              2.6   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging            5000.0            100
# 1   5000 mAh Battery with 33W Fast Charging            5000.0             33
# 2   5000 mAh Battery with 15W Fast Charging            5000.0             15
# 3       5000 mAh Battery with Fast Charging            5000.0              0
# 4   5000 mAh Battery with 67W Fast Charging            5000.0             67
#
#    ram_capacity  internal_memory  \
# 0          12.0            256.0
# 1           6.0            128.0
# 2           4.0             64.0
# 3           6.0            128.0
# 4           6.0            128.0
#
#                                              display  screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...         6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...         6.59
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...         6.60
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...         6.55
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...         6.70
#
#    refresh_rate    resolution  \
# 0           120  1440 x 3216
# 1           120  1080 x 2412
# 2            90  1080 x 2408
# 3           120  1080 x 2400
# 4           120  1080 x 2412
#
#                                               camera num_rear_cameras  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...                3
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...                3
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...                3
#
#   num_front_cameras                              card           os  \
# 0                 1         Memory Card Not Supported  Android v13
# 1                 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2                 1  Memory Card Supported, upto 1 TB  Android v13
# 3                 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 4                 1         Memory Card Not Supported  Android v13
#
#   primary_camera_rear primary_camera_front
# 0                  50                   16
# 1                  64                   16
# 2                  50                   13
# 3                  50                   16
# 4                 108                   16

# %%
df1[df1['card'] == 'Memory Card (Hybrid)']
# Out:
#      index brand_name                                      model  price  \
# 25      27    samsung                   Samsung Galaxy S20 FE 5G  31239
# 80      82   motorola                       Motorola Moto G72 4G  15999
# 147    149    samsung                      Samsung Galaxy M34 5G  16999
# 151    153   motorola                          Motorola Moto G52  11999
# 177    180       vivo                                Vivo Y75 5G  21990
# 203    206   motorola        Motorola Moto G52 (6GB RAM + 128GB)  12999
# 247    250   motorola                          Motorola Moto G73  25999
# 253    256     xiaomi                Xiaomi Redmi Note 11 Pro 5G  17990
# 279    283       vivo                               Vivo V23e 5G  21994
# 303    307     xiaomi                    Xiaomi Mi 11 Lite NE 5G  21890
# 437    443       poco                                Poco X3 Pro  19650
# 466    472     xiaomi  Xiaomi Mi 11 Lite NE 5G (8GB RAM + 128GB)  22999
# 482    489       sony                           Sony Xperia 5 II  69990
# 484    491       sony        Sony Xperia 1 IV (12GB RAM + 512GB)  92980
# 508    515     realme                               Realme Q5 5G  14990
# 570    582      nokia                                  Nokia G60  28498
# 591    604       vivo                                   Vivo V21  24999
# 613    628       vivo                                Vivo V21 5G  23994
# 616    631       sony                           Sony Xperia 1 II  69999
# 645    664       vivo                                  Vivo V25e  19990
# 662    682         lg                               LG Velvet 5G  54999
# 677    698      honor                              Honor Play 30   9999
# 679    700       sony                        Sony Xperia 5 IV 5G  82199
# 700    722       vivo                                  Vivo V21s  29999
# 744    769   motorola                       Motorola Moto G52 5G  16999
# 832    862       sony                          Sony Xperia 10 II  27999
# 846    877     huawei                            Huawei Nova Y61  21990
# 903    941        zte                               ZTE Axon 30S  19999
# 904    942      honor                                   Honor X6  13999
# 906    944        tcl                                  TCL Ion X   8990
#
#      rating                                                sim  has_5g  \
# 25     88.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 80     83.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC   False
# 147    84.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 151    75.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC   False
# 177    82.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 203    79.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC   False
# 247    85.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 253    81.0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True
# 279    84.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 303    83.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True
# 437    82.0         Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster   False
# 466    86.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True
# 482    86.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 484     NaN            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 508    78.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 570    81.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 591    83.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 613    85.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 616    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 645    84.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 662    85.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 677    68.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 679    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 700    86.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 744    76.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 832    75.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC   False
# 846    63.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 903    82.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 904    71.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 906    60.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
#
#      has_nfc  has_ir_blaster                                        processor  \
# 25      True           False    Snapdragon 865, Octa Core, 2.84 GHz Processor
# 80      True           False         Helio  G99, Octa Core, 2.2 GHz Processor
# 147     True           False        Exynos 1200, Octa Core, 2.4 GHz Processor
# 151     True           False     Snapdragon 680, Octa Core, 2.4 GHz Processor
# 177    False           False  Dimensity  700 5G, Octa Core, 2.2 GHz Processor
# 203     True           False     Snapdragon 680, Octa Core, 2.4 GHz Processor
# 247     True           False      Dimensity 930, Octa Core, 2.2 GHz Processor
# 253    False            True     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 279    False           False  Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 303     True            True  Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 437    False            True    Snapdragon 860, Octa Core, 2.96 GHz Processor
# 466     True            True  Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 482     True           False   Snapdragon 865 , Octa Core, 2.84 GHz Processor
# 484     True           False    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 508    False           False     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 570     True           False    Snapdragon  695, Octa Core, 2.2 GHz Processor
# 591    False           False     Dimensity 800U, Octa Core, 2.4 GHz Processor
# 613    False           False     Dimensity 800U, Octa Core, 2.4 GHz Processor
# 616     True           False  Snapdragon  865 , Octa Core, 2.84 GHz Processor
# 645    False           False          Helio G99, Octa Core, 2.2 GHz Processor
# 662     True           False   Snapdragon  765G, Octa Core, 2.4 GHz Processor
# 677    False           False    Snapdragon 480+, Octa Core, 2.2 GHz Processor
# 679     True           False    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 700     True           False    Dimensity 800U , Octa Core, 2.4 GHz Processor
# 744     True           False     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 832     True           False      Snapdragon  665, Octa Core, 2 GHz Processor
# 846    False           False                              Octa Core Processor
# 903     True           False    Snapdragon 870 , Octa Core, 3.2 GHz Processor
# 904    False           False            Helio G25, Octa Core, 2 GHz Processor
# 906    False           False            Helio G25, Octa Core, 2 GHz Processor
#
#         processor_name processor_brand  num_cores  processor_speed  \
# 25      Snapdragon 865      snapdragon  Octa Core             2.84
# 80          Helio  G99           helio  Octa Core             2.20
# 147        Exynos 1200          exynos  Octa Core             2.40
# 151     Snapdragon 680      snapdragon  Octa Core             2.40
# 177  Dimensity  700 5G       dimensity  Octa Core             2.20
# 203     Snapdragon 680      snapdragon  Octa Core             2.40
# 247      Dimensity 930       dimensity  Octa Core             2.20
# 253     Snapdragon 695      snapdragon  Octa Core             2.20
# 279  Dimensity  810 5G       dimensity  Octa Core             2.40
# 303   Snapdragon  778G      snapdragon  Octa Core             2.40
# 437     Snapdragon 860      snapdragon  Octa Core             2.96
# 466   Snapdragon  778G      snapdragon  Octa Core             2.40
# 482     Snapdragon 865      snapdragon  Octa Core             2.84
# 484  Snapdragon 8 Gen1      snapdragon  Octa Core             3.00
# 508     Snapdragon 695      snapdragon  Octa Core             2.20
# 570    Snapdragon  695      snapdragon  Octa Core             2.20
# 591     Dimensity 800U       dimensity  Octa Core             2.40
# 613     Dimensity 800U       dimensity  Octa Core             2.40
# 616    Snapdragon  865      snapdragon  Octa Core             2.84
# 645          Helio G99           helio  Octa Core             2.20
# 662   Snapdragon  765G      snapdragon  Octa Core             2.40
# 677    Snapdragon 480+      snapdragon  Octa Core             2.20
# 679  Snapdragon 8 Gen1      snapdragon  Octa Core             3.00
# 700     Dimensity 800U       dimensity  Octa Core             2.40
# 744     Snapdragon 695      snapdragon  Octa Core             2.20
# 832    Snapdragon  665      snapdragon  Octa Core             2.00
# 846               None            None  Octa Core              NaN
# 903     Snapdragon 870      snapdragon  Octa Core             3.20
# 904          Helio G25           helio  Octa Core             2.00
# 906          Helio G25           helio  Octa Core             2.00
#
#                            ram                                    battery  \
# 25    8 GB RAM, 128 GB inbuilt        4500 mAh Battery with Fast Charging
# 80    6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 147   6 GB RAM, 128 GB inbuilt    6000 mAh Battery with 25W Fast Charging
# 151    4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 177   8 GB RAM, 128 GB inbuilt    5000 mAh Battery with 18W Fast Charging
# 203   6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 247   8 GB RAM, 256 GB inbuilt    5000 mAh Battery with 30W Fast Charging
# 253    6 GB RAM, 64 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 279   8 GB RAM, 128 GB inbuilt    4050 mAh Battery with 44W Fast Charging
# 303   6 GB RAM, 128 GB inbuilt    4250 mAh Battery with 33W Fast Charging
# 437   6 GB RAM, 128 GB inbuilt    5160 mAh Battery with 33W Fast Charging
# 466   8 GB RAM, 128 GB inbuilt    4250 mAh Battery with 33W Fast Charging
# 482   8 GB RAM, 128 GB inbuilt    4000 mAh Battery with 21W Fast Charging
# 484  12 GB RAM, 512 GB inbuilt    5000 mAh Battery with 30W Fast Charging
# 508   6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 60W Fast Charging
# 570   6 GB RAM, 128 GB inbuilt    4500 mAh Battery with 20W Fast Charging
# 591   8 GB RAM, 128 GB inbuilt    4000 mAh Battery with 33W Fast Charging
# 613   8 GB RAM, 128 GB inbuilt    4000 mAh Battery with 33W Fast Charging
# 616   8 GB RAM, 256 GB inbuilt    4000 mAh Battery with 21W Fast Charging
# 645   8 GB RAM, 256 GB inbuilt    4500 mAh Battery with 44W Fast Charging
# 662   6 GB RAM, 128 GB inbuilt    4300 mAh Battery with 25W Fast Charging
# 677   4 GB RAM, 128 GB inbuilt                           5000 mAh Battery
# 679   8 GB RAM, 256 GB inbuilt    5000 mAh Battery with 30W Fast Charging
# 700   8 GB RAM, 128 GB inbuilt    4000 mAh Battery with 33W Fast Charging
# 744    4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 832   4 GB RAM, 128 GB inbuilt    3600 mAh Battery with 18W Fast Charging
# 846    4 GB RAM, 64 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 903   6 GB RAM, 128 GB inbuilt    4200 mAh Battery with 55W Fast Charging
# 904    4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 10W Fast Charging
# 906    3 GB RAM, 32 GB inbuilt    3000 mAh Battery with 10W Fast Charging
#
#      battery_capacity  fast_charging  ram_capacity  internal_memory  \
# 25             4500.0              0           8.0            128.0
# 80             5000.0             33           6.0            128.0
# 147            6000.0             25           6.0            128.0
# 151            5000.0             33           4.0             64.0
# 177            5000.0             18           8.0            128.0
# 203            5000.0             33           6.0            128.0
# 247            5000.0             30           8.0            256.0
# 253            5000.0             67           6.0             64.0
# 279            4050.0             44           8.0            128.0
# 303            4250.0             33           6.0            128.0
# 437            5160.0             33           6.0            128.0
# 466            4250.0             33           8.0            128.0
# 482            4000.0             21           8.0            128.0
# 484            5000.0             30          12.0            512.0
# 508            5000.0             60           6.0            128.0
# 570            4500.0             20           6.0            128.0
# 591            4000.0             33           8.0            128.0
# 613            4000.0             33           8.0            128.0
# 616            4000.0             21           8.0            256.0
# 645            4500.0             44           8.0            256.0
# 662            4300.0             25           6.0            128.0
# 677            5000.0             -1           4.0            128.0
# 679            5000.0             30           8.0            256.0
# 700            4000.0             33           8.0            128.0
# 744            5000.0             33           4.0             64.0
# 832            3600.0             18           4.0            128.0
# 846            5000.0             22           4.0             64.0
# 903            4200.0             55           6.0            128.0
# 904            5000.0             10           4.0             64.0
# 906            3000.0             10           3.0             32.0
#
#                                                display  screen_size  \
# 25   6.5 inches, 1080 x 2400 px, 120 Hz Display wit...         6.50
# 80   6.55 inches, 1080 x 2400 px, 120 Hz Display wi...         6.55
# 147  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...         6.50
# 151  6.6 inches, 2460 x 1080 px, 90 Hz Display with...         6.60
# 177  6.58 inches, 1080 x 2408 px Display with Water...         6.58
# 203  6.6 inches, 2460 x 1080 px, 90 Hz Display with...         6.60
# 247  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...         6.50
# 253  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...         6.67
# 279  6.44 inches, 1080 x 2400 px Display with Water...         6.44
# 303  6.55 inches, 1080 x 2400 px, 90 Hz Display wit...         6.55
# 437  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...         6.67
# 466  6.55 inches, 1080 x 2400 px, 90 Hz Display wit...         6.55
# 482         6.1 inches, 1080 x 2520 px, 120 Hz Display         6.10
# 484         6.5 inches, 1644 x 3840 px, 120 Hz Display         6.50
# 508  6.6 inches, 1080 x 2412 px, 120 Hz Display wit...         6.60
# 570  6.58 inches, 1080 x 2400 px, 120 Hz Display wi...         6.58
# 591  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...         6.44
# 613  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...         6.44
# 616                 6.5 inches, 1644 x 3840 px Display         6.50
# 645  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...         6.44
# 662  6.8 inches, 1080 x 2460 px Display with Water ...         6.80
# 677  6.5 inches, 720 x 1600 px Display with Water D...         6.50
# 679         6.1 inches, 1080 x 2520 px, 120 Hz Display         6.10
# 700  6.44 inches, 1080 x 2400 px, 90 Hz Display wit...         6.44
# 744  6.6 inches, 2460 x 1080 px, 90 Hz Display with...         6.60
# 832            6 inches, 1080 x 2520 px, 90 Hz Display         6.00
# 846  6.52 inches, 720 x 1600 px Display with Water ...         6.52
# 903         6.9 inches, 1080 x 2460 px, 120 Hz Display         6.90
# 904  6.5 inches, 720 x 1600 px Display with Water D...         6.50
# 906                    6 inches, 720 x 1440 px Display         6.00
#
#      refresh_rate    resolution  \
# 25            120  1080 x 2400
# 80            120  1080 x 2400
# 147           120  1080 x 2400
# 151            90  2460 x 1080
# 177            60  1080 x 2408
# 203            90  2460 x 1080
# 247           120  1080 x 2400
# 253           120  1080 x 2400
# 279            60  1080 x 2400
# 303            90  1080 x 2400
# 437           120  1080 x 2400
# 466            90  1080 x 2400
# 482           120  1080 x 2520
# 484           120  1644 x 3840
# 508           120  1080 x 2412
# 570           120  1080 x 2400
# 591            90  1080 x 2400
# 613            90  1080 x 2400
# 616            60  1644 x 3840
# 645            90  1080 x 2400
# 662            60  1080 x 2460
# 677            60   720 x 1600
# 679           120  1080 x 2520
# 700            90  1080 x 2400
# 744            90  2460 x 1080
# 832            90  1080 x 2520
# 846            60   720 x 1600
# 903           120  1080 x 2460
# 904            60   720 x 1600
# 906            60   720 x 1440
#
#                                                 camera num_rear_cameras  \
# 25   12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front...                3
# 80   108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...                3
# 147               64 MP Quad Rear & 32 MP Front Camera                4
# 151  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 177  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 203  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 247        50 MP + 8 MP Dual Rear & 16 MP Front Camera                2
# 253  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...                3
# 279  50 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...                3
# 303  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...                3
# 437               48 MP Quad Rear & 20 MP Front Camera                4
# 466  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...                3
# 482  12 MP + 12 MP + 12 MP Triple Rear & 8 MP Front...                3
# 484               12 MP Quad Rear & 12 MP Front Camera                4
# 508  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 570  50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...                3
# 591  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...                3
# 613  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...                3
# 616                12 MP Quad Rear & 8 MP Front Camera                4
# 645  64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front ...                3
# 662  48 MP + 8 MP + 5 MP Triple Rear & 16 MP Front ...                3
# 677                     13 MP Rear & 5 MP Front Camera                1
# 679  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...                3
# 700  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...                3
# 744  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 832  12 MP + 8 MP + 8 MP Triple Rear & 8 MP Front C...                3
# 846       50 MP + 2 MP Triple Rear & 5 MP Front Camera                3
# 903               50 MP Quad Rear & 16 MP Front Camera                4
# 904  50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...                3
# 906                     13 MP Rear & 5 MP Front Camera                1
#
#     num_front_cameras                  card             os  \
# 25                  1  Memory Card (Hybrid)    Android v10
# 80                  1  Memory Card (Hybrid)    Android v12
# 147                 1  Memory Card (Hybrid)    Android v12
# 151                 1  Memory Card (Hybrid)    Android v12
# 177                 1  Memory Card (Hybrid)    Android v12
# 203                 1  Memory Card (Hybrid)    Android v12
# 247                 1  Memory Card (Hybrid)    Android v13
# 253                 1  Memory Card (Hybrid)    Android v11
# 279                 1  Memory Card (Hybrid)    Android v12
# 303                 1  Memory Card (Hybrid)    Android v11
# 437                 1  Memory Card (Hybrid)    Android v11
# 466                 1  Memory Card (Hybrid)    Android v11
# 482                 1  Memory Card (Hybrid)    Android v10
# 484                 1  Memory Card (Hybrid)    Android v12
# 508                 1  Memory Card (Hybrid)    Android v12
# 570                 1  Memory Card (Hybrid)    Android v12
# 591                 1  Memory Card (Hybrid)    Android v11
# 613                 1  Memory Card (Hybrid)    Android v11
# 616                 1  Memory Card (Hybrid)    Android v10
# 645                 1  Memory Card (Hybrid)    Android v12
# 662                 1  Memory Card (Hybrid)    Android v10
# 677                 1  Memory Card (Hybrid)    Android v11
# 679                 1  Memory Card (Hybrid)    Android v12
# 700                 1  Memory Card (Hybrid)    Android v12
# 744                 1  Memory Card (Hybrid)    Android v12
# 832                 1  Memory Card (Hybrid)  Android v10.0
# 846                 1  Memory Card (Hybrid)       EMUI v12
# 903                 1  Memory Card (Hybrid)    Android v12
# 904                 1  Memory Card (Hybrid)    Android v12
# 906                 1  Memory Card (Hybrid)        Android
#
#     primary_camera_rear primary_camera_front
# 25                   12                   32
# 80                  108                   16
# 147                  64                   32
# 151                  50                   16
# 177                  50                   16
# 203                  50                   16
# 247                  50                   16
# 253                 108                   16
# 279                  50                   44
# 303                  64                   20
# 437                  48                   20
# 466                  64                   20
# 482                  12                    8
# 484                  12                   12
# 508                  50                   16
# 570                  50                    8
# 591                  64                   44
# 613                  64                   44
# 616                  12                    8
# 645                  64                   32
# 662                  48                   16
# 677                  13                    5
# 679                  12                   12
# 700                  64                   44
# 744                  50                   16
# 832                  12                    8
# 846                  50                    5
# 903                  50                   16
# 904                  50                    5
# 906                  13                    5

# %%
df1.loc[temp_df.index, 'card'] = 'Not Specified'

# %%
df1['extended_memory'] = df1['card'].apply(lambda x:'0' if 'Not' in x else x.split('upto')).str.get(-1).str.strip().str.replace('Memory Card Supported','Not Specified')

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor    Snapdragon  695
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor     Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 2          exynos  Octa Core              2.4    4 GB RAM, 64 GB inbuilt
# 3      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
# 4       dimensity  Octa Core              2.6   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging            5000.0            100
# 1   5000 mAh Battery with 33W Fast Charging            5000.0             33
# 2   5000 mAh Battery with 15W Fast Charging            5000.0             15
# 3       5000 mAh Battery with Fast Charging            5000.0              0
# 4   5000 mAh Battery with 67W Fast Charging            5000.0             67
#
#    ram_capacity  internal_memory  \
# 0          12.0            256.0
# 1           6.0            128.0
# 2           4.0             64.0
# 3           6.0            128.0
# 4           6.0            128.0
#
#                                              display  screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...         6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...         6.59
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...         6.60
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...         6.55
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...         6.70
#
#    refresh_rate    resolution  \
# 0           120  1440 x 3216
# 1           120  1080 x 2412
# 2            90  1080 x 2408
# 3           120  1080 x 2400
# 4           120  1080 x 2412
#
#                                               camera num_rear_cameras  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...                3
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...                3
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...                3
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...                3
#
#   num_front_cameras                              card           os  \
# 0                 1         Memory Card Not Supported  Android v13
# 1                 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2                 1  Memory Card Supported, upto 1 TB  Android v13
# 3                 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 4                 1         Memory Card Not Supported  Android v13
#
#   primary_camera_rear primary_camera_front extended_memory
# 0                  50                   16               0
# 1                  64                   16            1 TB
# 2                  50                   13            1 TB
# 3                  50                   16            1 TB
# 4                 108                   16               0

# %%
# df1[df1['os'].str.contains('Memory Card')]

# %%
df1.loc[temp_df.index, 'os'] = 'Not Specified'

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                        391
# Android v11                        274
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  29
# Android v10.0                       23
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# iOS v13                              4
# Android v11.0                        4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# Android v12.1                        2
# EMUI v12                             2
# HarmonyOS v2.0                       2
# Harmony v2.0                         2
# iOS v14.0                            2
# Android v5.1.1 (Lollipop)            2
# Android v6.0 (Marshmallow)           2
# Android v5.1 (Lollipop)              1
# Android v4.4.2 (KitKat)              1
# iOS v17                              1
# iOS v12.3                            1
# iOS v13.0                            1
# Not Specified                        1
# HarmonyOS v2                         1
# Pragati OS (Powered by Android)      1
# iOS v10                              1
# RTOS (Series 30+)                    1
# Hongmeng OS v3.0                     1
# Hongmeng OS v4.0                     1
# HarmonyOS                            1
# Android v7.1 (Nougat)                1
# Android                              1
# Android v9 (Pie)                     1
# Name: count, dtype: int64

# %%
def os_extractor(text):

  if 'Android' in text:
    return 'android'
  elif 'iOS' in text:
    return 'ios'
  elif 'Not Specified':
    return text
  elif 'Harmony' in text or 'Hongmeng' in text or 'EMUI' in text:
    return 'other'

# %%
# df1['os'] = df1['os'].apply(os_extractor)

# %%
export_df = df1.drop(columns=['index','sim','processor','ram','battery','display','camera','card'])

# %%
export_df.to_csv('smartphone_cleaned_v2.csv',index=False)
