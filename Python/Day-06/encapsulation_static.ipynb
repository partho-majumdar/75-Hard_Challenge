# %%
# Write oop class to handle the following scenario
''' 
- A user can create and view 2D coordinate
- A user can find out the distance of 2 coordinates
- A user can find out the distance of a coordinate from origin
- A user can check if a point lies  on a given line
- A user can find the distance between then given 2D point and a given line
'''

import math

class Point:
    def __init__(self, x, y):
        self.x_cod = x
        self.y_cod = y
    
    def __str__(self):
        return '({}, {})'.format(self.x_cod, self.y_cod)

    def distance(self, other):
        return math.sqrt(((self.x_cod - other.x_cod) ** 2) + ((self.y_cod - other.y_cod) ** 2))

    def distance_from_origin(self):
        return self.distance(Point(0, 0))

class Line:
    def __init__(self, A, B, C):
        self.A = A        
        self.B = B        
        self.C = C   

    def __str__(self):
        return '{}x + {}y + {} = 0'.format(self.A, self.B, self.C)  


    def point_on_line(line, point):
        if ((line.A * point.x_cod) + (line.B * point.y_cod) + line.C) == 0:
            return 'point on line'
        else:
            return 'point outside line'
        
    def shortest_distance(line, point):
        return abs(line.A * point.x_cod + line.B * point.y_cod + line.C) / math.sqrt(line.A ** 2 + line.B ** 2)


obj1 = Point(0, 0)
obj2 = Point(1, 1)
print(obj1)
print(obj2)
print(obj1.distance(obj2))
obj2.distance_from_origin()

line1 = Line(3, 5, 4)
print(line1)

line2 = Line(1, 1, -2)
point2 = Point(1, 1)
print(line2)
print(point2)
line2.point_on_line(point2)
line2.shortest_distance(point2)
# Out:
# (0, 0)
# (1, 1)
# 1.4142135623730951
# 3x + 5y + 4 = 0
# 1x + 1y + -2 = 0
# (1, 1)
# 0.0

# %%
# -------------- Make attribute outside the class

class Person:
    def __init__(self, name_input, country_input):
        self.name = name_input
        self.country = country_input
    
    def greet(self):
        if self.country == 'bd':
            print("hello", self.name)
        else:
            print("hello world")

p1 = Person('jhinku', 'bd')
p1.name
p1.country
p1.greet()
p1.gender = 'sigma male'
p1.gender
# Out:
# hello jhinku
# 'sigma male'

# %%
# -------------------- Reference Variable

class Person:
    def __init__(self):
        self.name = 'alpha'
        self.gender = 'male'

p = Person() # here 'p' is reference variable which contains reference/address of the object that has been created
q = p # both 'p' & 'q' point to the same memory address
print(id(p))
print(id(q))

# change attribute value with the help of 2nd object
print(p.name)
print(q.name)
q.name = 'sigma'
print(p.name)
print(q.name)
# Out:
# 2690301924016
# 2690301924016
# alpha
# alpha
# sigma
# sigma

# %%
# ---------------- Pass by Reference
# pass class object as input to the function

class Person:
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender

# outside class -> function
def greet(person):
    print("this is", person.name, "and i am", person.gender)
    p1 = Person('tinku', 'pookie')
    return p1

p2 = Person('jhinku', 'sigma male')
x = greet(p2)
print(x.name)
print(x.gender)
# Out:
# this is jhinku and i am sigma male
# tinku
# pookie

# %%
# Pass by Reference
# when i want to pass object as input i pass the address of object

class Person:
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender

# outside class -> function
def greet(person):
    print(id(person))
    print("this is", person.name, "and i am", person.gender)

p2 = Person('jhinku', 'sigma male')
print(id(p2))
greet(p2)
# Out:
# 2690301924352
# 2690301924352
# this is jhinku and i am sigma male

# %%
class Person:
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender

# outside class -> function  
def greet(person):
    person.name = 'aaa'
    print(person.name)

p2 = Person('jhinku', 'sigma male')
greet(p2)
print(p2.name)

# both point to the same object hence both will be change
# Out:
# aaa
# aaa

# %%
# all object in python is mutable(address will be same) if it is immutable address will be different

class Person:
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender

# outside class -> function
def greet(person):
    person.name = 'aaa'
    return person

p1 = Person('jhinku', 'sigma male')
print(id(p1))
p2 = greet(p1)
print(id(p2))
# Out:
# 2974027087360
# 2974027087360

# %%
# ------------------- Encapsulation (public vs private -> use __variable_name)
# instance variable (for different object value is different)
# name, country is instance variable
class Person:
    def __init__(self, name_input, country_input):
        self.name = name_input
        self.country = country_input
    
p1 = Person("aa", "bd")
p2 = Person("bb", "ind")
print(p1.name)
print(p2.name)
# Out:
# aa
# bb

# %%
''' 
# Small banking application

class ATM:
    # constructor -> function in class -> to run no need to call constructor, when create object it will execute automatically
    def __init__(self):
        self.pin = ''
        self.balance = 0
        self.menu()
    
    def menu(self):
        user_input = input("""
            How can i help you?
            1. For create pin
            2. For change pin
            3. For check balance
            4. For withdraw
            5. Exit
        """)

        if user_input == '1':
            # create pin
            self.create_pin()
    
        elif user_input == '2':
            # change pin
            self.change_pin()
        
        elif user_input == '3':
            # check balance
            self.check_balance()

        elif user_input == '4':
            # withdraw money
            self.withdraw_money()

        elif user_input == '5':                 
            pass
        
        else:
            print("Enter valid number")

    def create_pin(self):
        user_pin = input("Enter your pin: ")
        user_balance = int(input("Enter your balance: "))
        self.pin = user_pin
        self.balance = user_balance
        print("Pin successfully created")
        self.menu()

    def change_pin(self):
        old_pin = input("Enter old pin: ")
        if old_pin == self.pin:
            new_pin = input("Enter num pin: ")
            self.pin = new_pin
            print("New pin successfully changed")
            self.menu()
        else:
            print("pin cannot changed")

    def check_balance(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            print("Your balance is: ",self.balance)
        else:
            print("Wrong password")
        self.menu()

    def withdraw_money(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            user_money = int(input("How much money want to withdraw: "))
            if user_money > self.balance:
                print("Insufficient ballance")
                self.menu()
            elif user_money <= self.balance:
                self.balance -= user_money
                print(user_money, "tk successfully withdraw")
                print("Your new balance is: ",self.balance)
                self.menu()
        else:
            print("Wrong password")
            self.menu()

# creating object
obj = ATM()
obj.create_pin()
obj.balance = 'hehehe' # as balance is public so this line work and now my balance is string
obj.withdraw_money() # this give me error cause previous line balance = string now balance = int

so i don't want no one change my variable, method value so make it private
'''


# Small banking application

class ATM:
    # constructor -> function in class -> to run no need to call constructor, when create object it will execute automatically
    def __init__(self):
        self.pin = ''
        self.__balance = 0
        # self.menu()
    
    def menu(self):
        user_input = input("""
            How can i help you?
            1. For create pin
            2. For change pin
            3. For check balance
            4. For withdraw
            5. Exit
        """)

        if user_input == '1':
            # create pin
            self.create_pin()
    
        elif user_input == '2':
            # change pin
            self.change_pin()
        
        elif user_input == '3':
            # check balance
            self.check_balance()

        elif user_input == '4':
            # withdraw money
            self.withdraw_money()

        elif user_input == '5':                 
            # break
            pass
        
        else:
            print("Enter valid number")

    def create_pin(self):
        user_pin = input("Enter your pin: ")
        user_balance = int(input("Enter your balance: "))
        self.pin = user_pin
        self.__balance = user_balance
        print("Pin successfully created")
        self.menu()

    def change_pin(self):
        old_pin = input("Enter old pin: ")
        if old_pin == self.pin:
            new_pin = input("Enter num pin: ")
            self.pin = new_pin
            print("New pin successfully changed")
            self.menu()
        else:
            print("pin cannot changed")

    def check_balance(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            print("Your balance is: ",self.__balance)
        else:
            print("Wrong password")
        self.menu()

    def withdraw_money(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            user_money = int(input("How much money want to withdraw: "))
            if user_money > self.__balance:
                print("Insufficient ballance")
                self.menu()
            elif user_money <= self.__balance:
                self.__balance -= user_money
                print(user_money, "tk successfully withdraw")
                print("Your new balance is: ",self.__balance)
                self.menu()
        else:
            print("Wrong password")
            self.menu()

# creating object
obj = ATM()
obj.create_pin()
# obj.balance = 'hehehe' # now this line will give error
obj.withdraw_money() 

''' 
obj.__balance = 'hehehe' # this will not give error
when i make anything private in memory it create _className__variableName (_ATM__balance) but here it __balance this is new variable

obj._ATM__balance = 'hehehe" # this will give error

Nothing is truly private in python cause -> python made for adult

Getter, Setter method for make private method -> public (so that other can use)
'''

# %%
''' 
# Small banking application

class ATM:
    # constructor -> function in class -> to run no need to call constructor, when create object it will execute automatically
    def __init__(self):
        self.pin = ''
        self.balance = 0
        # self.menu()
    
    def menu(self):
        user_input = input("""
            How can i help you?
            1. For create pin
            2. For change pin
            3. For check balance
            4. For withdraw
            5. Exit
        """)

        if user_input == '1':
            # create pin
            self.create_pin()
    
        elif user_input == '2':
            # change pin
            self.change_pin()
        
        elif user_input == '3':
            # check balance
            self.check_balance()

        elif user_input == '4':
            # withdraw money
            self.withdraw_money()

        elif user_input == '5':                 
            pass
        
        else:
            print("Enter valid number")

    def create_pin(self):
        user_pin = input("Enter your pin: ")
        user_balance = int(input("Enter your balance: "))
        self.pin = user_pin
        self.balance = user_balance
        print("Pin successfully created")
        self.menu()

    def change_pin(self):
        old_pin = input("Enter old pin: ")
        if old_pin == self.pin:
            new_pin = input("Enter num pin: ")
            self.pin = new_pin
            print("New pin successfully changed")
            self.menu()
        else:
            print("pin cannot changed")

    def check_balance(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            print("Your balance is: ",self.balance)
        else:
            print("Wrong password")
        self.menu()

    def withdraw_money(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            user_money = int(input("How much money want to withdraw: "))
            if user_money > self.balance:
                print("Insufficient ballance")
                self.menu()
            elif user_money <= self.balance:
                self.balance -= user_money
                print(user_money, "tk successfully withdraw")
                print("Your new balance is: ",self.balance)
                self.menu()
        else:
            print("Wrong password")
            self.menu()

# creating object
obj = ATM()
obj.create_pin()
obj.balance = 'hehehe' # as balance is public so this line work and now my balance is string
obj.withdraw_money() # this give me error cause previous line balance = string now balance = int

so i don't want no one change my variable, method value so make it private
'''


# Small banking application
# Getter, Setter method for make private method -> public (so that other can use)
class ATM:
    # constructor -> function in class -> to run no need to call constructor, when create object it will execute automatically
    def __init__(self):
        self.pin = ''
        self.__balance = 0
        # self.menu()
    
    def get_balance(self):
        return self.__balance

    def set_balance(self, new_balance):
        if (type(new_balance) == int):
            self.__balance = new_balance
        else:
            print("kya kar raha hai tu, pitega vai")

    def menu(self):
        user_input = input("""
            How can i help you?
            1. For create pin
            2. For change pin
            3. For check balance
            4. For withdraw
            5. Exit
        """)

        if user_input == '1':
            # create pin
            self.create_pin()
    
        elif user_input == '2':
            # change pin
            self.change_pin()
        
        elif user_input == '3':
            # check balance
            self.check_balance()

        elif user_input == '4':
            # withdraw money
            self.withdraw_money()

        elif user_input == '5':                 
            # break
            pass
        
        else:
            print("Enter valid number")

    def create_pin(self):
        user_pin = input("Enter your pin: ")
        user_balance = int(input("Enter your balance: "))
        self.pin = user_pin
        self.__balance = user_balance
        print("Pin successfully created")
        self.menu()

    def change_pin(self):
        old_pin = input("Enter old pin: ")
        if old_pin == self.pin:
            new_pin = input("Enter num pin: ")
            self.pin = new_pin
            print("New pin successfully changed")
            self.menu()
        else:
            print("pin cannot changed")

    def check_balance(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            print("Your balance is: ",self.__balance)
        else:
            print("Wrong password")
        self.menu()

    def withdraw_money(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            user_money = int(input("How much money want to withdraw: "))
            if user_money > self.__balance:
                print("Insufficient ballance")
                self.menu()
            elif user_money <= self.__balance:
                self.__balance -= user_money
                print(user_money, "tk successfully withdraw")
                print("Your new balance is: ",self.__balance)
                self.menu()
        else:
            print("Wrong password")
            self.menu()

# creating object
obj = ATM()
obj.get_balance()
# but 
# obj.set_balance('hehehe') # this will give error so make condition in set balance
# Out:
# 0

# %%
# List of object

class Person:
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender

p1 = Person("aa", "male")
p2 = Person("bb", "female")
p3 = Person("cc", "male")

L = [p1, p2, p3] # list of object as there is no str so print only memory address

for i in L:
    print(i.name, i.gender)

s = {p1, p2, p3}
for i in s:
    print(i.name)

d = {
    'p1': p1,
    'p2': p2,
    'p3': p3
}
for (keys, values) in d.items():
    print(keys, values.name, values.gender)
# Out:
# aa male
# bb female
# cc male
# bb
# aa
# cc
# p1 aa male
# p2 bb female
# p3 cc male

# %%
# ------------------- Static variable(class variable) -> for every object value is same vs instance variable(object variable) -> for every object the value is different)

class ATM:

    __counter = 1

    # constructor -> function in class -> to run no need to call constructor, when create object it will execute automatically
    def __init__(self):
        self.pin = ''
        self.__balance = 0
        self.cid = ATM.__counter # static variable used with class name, instance variable used with self
        ATM.__counter += 1
        # self.menu()

    @staticmethod # no need to create object i can use through class name
    def get_counter():
        return ATM.__counter
    
    def get_balance(self):
        return self.__balance

    def set_balance(self, new_balance):
        if ( type(new_balance) == int):
            self.__balance = new_balance
        else:
            print("kya kar raha hai tu, pitega vai")

    def menu(self):
        user_input = input("""
            How can i help you?
            1. For create pin
            2. For change pin
            3. For check balance
            4. For withdraw
            5. Exit
        """)

        if user_input == '1':
            # create pin
            self.create_pin()
    
        elif user_input == '2':
            # change pin
            self.change_pin()
        
        elif user_input == '3':
            # check balance
            self.check_balance()

        elif user_input == '4':
            # withdraw money
            self.withdraw_money()

        elif user_input == '5':                 
            # break
            pass
        
        else:
            print("Enter valid number")

    def create_pin(self):
        user_pin = input("Enter your pin: ")
        user_balance = int(input("Enter your balance: "))
        self.pin = user_pin
        self.__balance = user_balance
        print("Pin successfully created")
        self.menu()

    def change_pin(self):
        old_pin = input("Enter old pin: ")
        if old_pin == self.pin:
            new_pin = input("Enter num pin: ")
            self.pin = new_pin
            print("New pin successfully changed")
            self.menu()
        else:
            print("pin cannot changed")

    def check_balance(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            print("Your balance is: ",self.__balance)
        else:
            print("Wrong password")
        self.menu()

    def withdraw_money(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            user_money = int(input("How much money want to withdraw: "))
            if user_money > self.__balance:
                print("Insufficient ballance")
                self.menu()
            elif user_money <= self.__balance:
                self.__balance -= user_money
                print(user_money, "tk successfully withdraw")
                print("Your new balance is: ",self.__balance)
                self.menu()
        else:
            print("Wrong password")
            self.menu()

# %%
c1 = ATM()

# %%
c2 = ATM()

# %%
c3 = ATM()

# %%
c1.cid
# Out:
# 1

# %%
c2.cid
# Out:
# 2

# %%
c3.cid
# Out:
# 3

# %%
ATM.counter = 'hehehe'

# %%
c4 = ATM()

# %%
# c4.get_counter() # error cause no argument in getter method but pass 1
ATM.get_counter()
# Out:
# 6
